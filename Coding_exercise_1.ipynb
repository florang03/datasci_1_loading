# %% [markdown]
# <a href="https://colab.research.google.com/github/florang03/datasci_1_loading/blob/main/Coding_exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **CSV_Dataset 1**:
# Information about home infusion therapy providers, as of Sept 8, 2026
#
# **Columns**
#
# **1. Enrollment ID**
# *  Contians the dentification number given by CMS, for providers that are in network with medicare.
#
# **2. Buisness Name**
#
# *   Has the names of the practice.
#
# **3. Street Address Line_1**
#
# *  Has the street address of the practice.
#
# **4. Street Address line_2**
#
# *   Has the apartment or suite numbers, if applicable.
#
# **5. City**
#
# *   Has the city in which the practice resides.
#
# **6. State**
# * Has the state in which the practice resides.
#
# **7. Zip**
# * Has the zip code.
#
# **8. Practice Location Phone Number**
# * Contains the contact information for the specialty.
#
# **9. Specialty Name**
# * Has the type and specific specialty description.
#
# **10. Geographic Location Type Description**
# * Has the geographic description of the practice.
#
# **11. Geographic Location City Name**
# * Has the city in which the practice resides, if applicabkle.
#
# **12. Geographic Location State Code**
# * Has the state codes in which the practice resides.
#
# **13. Geographic Location Zip Code**
# * Has the geographic zip, if applicable.
#
# **14. State County Name**
# * Has the count in which the practice resides, if applicable.

# %%
df1 = '/content/Home_Infusion_Therapy_Providers_Sep_08_2026.csv'
read_csv1 = pd.read_csv(df1)
read_csv1.head(11)
# Out:
#       Enrollment ID          Legal Business Name Street Address Line 1  \
# 0   O20201116001628      CRESCENT HEALTHCARE INC       5431 SW 35TH DR
# 1   O20250730000500           KABAFUSION CO, LLC   12450 E ARAPAHOE RD
# 2   O20210121000184            I V SOLUTIONS LLC         165 HANSEN CT
# 3   O20231019000440         PERPETUAL MOBILE MED  5015 EAGLE ROCK BLVD
# 4   O20220203001062         MKARE MANAGEMENT INC        147 AUBURN RDG
# 5   O20250428002383               INFUPHARMA LLC       1239 NE 8TH AVE
# 6   O20260127003422            KABAFUSION TN LLC         2970 SIDCO DR
# 7   O20260325003657                   AGIOS CORP         1314 S BAY ST
# 8   O20220509002548  FACTOR ONE SOURCE PHARM LLC          217 GLENN ST
# 9   O20220509002548  FACTOR ONE SOURCE PHARM LLC          217 GLENN ST
# 10  O20220509002548  FACTOR ONE SOURCE PHARM LLC          217 GLENN ST
#
#    Street Address Line 2             City State    ZIP Code  \
# ...

# %% [markdown]
# **CSV Dataset_2**:
# Information about opiod treatment providers, as of Sept 18, 2026
# Columns
#
# **1. NPI**
#
# * Contains the national provider identifier.
#
# **2. Provider Name**
#
# * Contains the name of the practice.
#
# **3. Street Address Line 1**
#
# * Contains the street address of the practice.
#
# **4. Street Address Line 2**
#
# * contains the apartment or suite numbers, if applicable.
#
# **5. City**
#
# *   Has the city in which the practice resides.
#
# **6. State**
# * Has the state in which the practice resides.
#
# **7. Zip**
# * Has the zip code.
#
# **8. Medicare ID effective Date**
#
# * Contains the date in which the practic's medicare ID is becomes active.
#
# **9. Phone**
#
# * Contains the contact information of the practice.

# %%
df2 = '/content/Opioid_Treatment_Program_Providers_Sep_15_2026.csv'
read_csv2 = pd.read_csv(df2)
read_csv2.head(11)
# Out:
#                                                   NPI  \
# 0                                          1003008301
# 1                                          1003081399
# 2                               1003081399 1013055110
# 3                                          1003150004
# 4                                          1003362484
# 5                                          1003368945
# 6                                          1003511213
# 7                                          1003571647
# 8   1003581174 1043641293 1063012334 1215593488 12...
# 9   1003581174 1043641293 1063012334 1215593488 12...
# 10  1003581174 1043641293 1063012334 1215593488 12...
#
#                           PROVIDER NAME             ADDRESS LINE 1  \
# 0    CENTER FOR COMMUNITY ALTERNATIVES,               25 CHAPEL ST
# 1   BAART BEHAVIORAL HEALTH SERVICES IN            617 COMSTOCK RD
# 2   BAART BEHAVIORAL HEALTH SERVICES IN            617 COMSTOCK RD
# ...

# %% [markdown]
# **XLS_Dataset 1**: Contains the expenditures per patient
#
#
# **Columns**
#
# **1. Fiscal Year**
#
# *  Contains the year in which the data was obtained.
#
# **2. priority groups**
#
# *  Contains the expeditures made per priority group (1-8G) per fiscal year.
#
# **3. Non-enrolled Veterans**
#
# *  Contains the expenditures by non enrolled veterans per fiscal year.
#
# **4. Non-Veterans**
#
# *  Contains the expenditures by non veterans per fiscal year.

# %%
df3 = '/content/AvgCost_FINAL2.xlsx'
read_excel1 = pd.read_excel(df3)
read_excel1.head(11)
# Out:
#                                            Unnamed: 0      Unnamed: 1  \
# 0   Average Expenditures1 Per Patient by Healthcar...             NaN
# 1                                         Fiscal Year  Priority Group
# 2                                                 NaN               1
# 3                                                2000            8441
# 4                                                2001            8347
# 5                                                2002            8719
# 6                                                2003            9058
# 7                                                2004           10017
# 8                                                2005           10228
# 9                                                2006           10515
# 10                                               2007           10428
#
#     Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# ...

# %% [markdown]
# **XLS_Dataset 2**: Contains the types and counts of licensed and certified Healthcare Facility Beds
#
#
# **Columns**
#
# **1. County**
#
# *  Contains the name of the County in which the facility resides.
#
# **2. FAC_FDR**
#
# *  General Acute Care Hospitals: a health facility that has a governing body with overal administrative and professional responsibility
#
# **3. Facility_Count**
#
# * Contains the number of licensed general acute care hospitals.
#
# **4. Bed_Capacity**
#
# * Contains the overall number of licensed bed in a facility.
#
# **5. Acute Psychiatric Care**
#
# * Contains the number of beds licensed for acute psychiatric care.
#
# **6. Acute Respiratory Care**
#
# * Contains the number of beds licensed for acute respiratory care.
#
# **7. Burn**
#
# * Contains the number of bed licensed for burns.
#
# **8. Chemical Dependency Recover**
#
# * Contains the number of bed licensed for chemical dependency recovery.
#
# **9. Coronary Care**
#
# * Contains the number of bed licensed for Coronary Care.
#
# **10. Intesive Care**
#
# * Contains the number of bed licensed for intesive care.
#
# **11. Intensive Care Newborn Nursery**
#
# * Contains the number of bed licensed for intesive care newborn nursery.
#
# **12. Intermediate Care**
#
# * Contains the number of bed licensed for intermediate care.
#
# **13. Labor and Delivery**
#
# * Contains the number of bed licensed for labor and delivery.
#
# **14. Pediatric**
#
# * Contains the number of bed licensed for Pediatrics.
#
# **15. Pediatric Intensive Care Unit**
#
# * Contains the number of bed licensed for pediatric intesive care unit.
#
# **16. Perinatal**
#
# * Contains the number of bed licensed for perinatal.
#
# **17. Rehabilitation**
#
# * Contains the number of bed licensed for rehabilitation.
#
# **18. Renal Transplant**
#
# * Contains the number of bed licensed for renal transplant.
#
# **19. Unspecified Acute Care**
#
# * Contains the number of bed licensed for unspecified acute care.

# %%
df4 = '/content/ca_county_gach_bed_counts.xlsx'
read_excel2 = pd.read_excel(df4, sheet_name=2)
read_excel2.head(11)
# Out:
#    COUNTY_NAME                      FAC_FDR  FACILITY_COUNT  BED_CAPACITY  \
# 0       ALPINE  GENERAL ACUTE CARE HOSPITAL               0             0
# 1       SIERRA  GENERAL ACUTE CARE HOSPITAL               0             0
# 2       SUTTER  GENERAL ACUTE CARE HOSPITAL               1            14
# 3         MONO  GENERAL ACUTE CARE HOSPITAL               1            17
# 4     MARIPOSA  GENERAL ACUTE CARE HOSPITAL               1            18
# 5        MODOC  GENERAL ACUTE CARE HOSPITAL               2            20
# 6    CALAVERAS  GENERAL ACUTE CARE HOSPITAL               1            25
# 7       LASSEN  GENERAL ACUTE CARE HOSPITAL               1            25
# 8   SAN BENITO  GENERAL ACUTE CARE HOSPITAL               1            25
# 9      TRINITY  GENERAL ACUTE CARE HOSPITAL               1            25
# 10        INYO  GENERAL ACUTE CARE HOSPITAL               2            29
#
#     ACUTE PSYCHIATRIC CARE  ACUTE RESPIRATORY CARE  BURN  \
# ...

# %% [markdown]
# **XLS_Dataset 2**: Contains number of vetarns per priority groups per fiscal year.
#
#
# **Columns**
#
#
# **1. Fiscal Year**
#
# *  Contains the year in which the data was obtained.
#
# **2. priority groups**
#
# *  Contains the number of veterans per priority group (1-8G) per fiscal year.
#
# **3. Non-enrolled Veterans**
#
# *  Contains the number of non enrolled veterans per fiscal year.
#
# **4. Non-Veterans**
#
# *  Contains the number of non veterans per fiscal year.

# %%
df5 = '/content/PriorityGroup_FINAL3 1.xlsx'
read_excel = pd.read_excel(df5)
read_excel.head(11)
# Out:
#    Number of Veteran Patients by Healthcare Priority Group: FY2000 to FY2013  \
# 0                                                 NaN
# 1   Number of Veteran Patients by Healthcare Prior...
# 2                                         Fiscal Year
# 3                                                 NaN
# 4                                                2000
# 5                                                2001
# 6                                                2002
# 7                                                2003
# 8                                                2004
# 9                                                2005
# 10                                               2006
#
#          Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0               NaN         NaN         NaN         NaN         NaN
# 1               NaN         NaN         NaN         NaN         NaN
# 2   Priority Groups         NaN         NaN         NaN         NaN
# ...

# %% [markdown]
# **JSON_Dataset 1**: Contians information about medical providers that use cannabis treatment.
#
#
# **Columns**
#
# **1. County**
#
# *  Contains the county in which the practice resides.
#
# **2. City**
#
# *  Contians the city in which the practice resides.
#
# **3. Name**
#
# *  Contains the name of the provider.
#
# **4. Specialty**
#
# *  Contains the specialty of the practice.
#
# **5. Address**
#
# *  Contains the street address of the practice.
#
# **6. Address 2**
#
# * Contains the apartment or suite number of the practice.
#
# **7. State**
#
# * Contains the state in which the practice resides.
#
# **8. Zip**
#
# * Contains the zip code of where the practice resides.
#
# **9. Phone**
#
# * Contains the contact information of the practice.
#
# **10. NYS Physical Points**
#
# * Contains the coordinates in which the practice resides.

# %%
df6 = '/content/Cannabis.json'
read_json1 = pd.read_json(df6)
read_json1.head(11)
# Out:
#                    :id           :version                      :created_at  \
# 0   row-inn6-26ya_6f7p  rv-7phm~7urv~2w8g 2026-09-18 22:30:59.614000+00:00
# 1   row-65up_6n9n~9a53  rv-ethe-5ctg_7xpi 2026-09-18 22:30:59.614000+00:00
# 2   row-i7ce-md63~ehwv  rv-u63c.5tfx_p8pb 2026-09-18 22:30:59.614000+00:00
# 3   row-z42i~65ic_85px  rv-rp3s_8dey~ehy5 2026-09-18 22:30:59.614000+00:00
# 4   row-5rev_n6jb~4iqe  rv-s5mj.z523.4ef6 2026-09-18 22:30:59.614000+00:00
# 5   row-s4yr-dp97-nh39  rv-u29v.meps~mm9j 2026-09-18 22:30:59.614000+00:00
# 6   row-yisp_jmcy-mhdz  rv-r6sx.r5h5_q5te 2026-09-18 22:30:59.614000+00:00
# 7   row-kxmh_w7d3.htvg  rv-6q3w~fm3s-wisp 2026-09-18 22:30:59.614000+00:00
# 8   row-egrp-7s27-jwkb  rv-5y7c-qy3r_c7nq 2026-09-18 22:30:59.614000+00:00
# 9   row-w9m8.xfad~ds5u  rv-s83r-6t8c-kvex 2026-09-18 22:30:59.614000+00:00
# 10  row-ybeq~3efy~sjp9  rv-fiac.kzjr~5wze 2026-09-18 22:30:59.614000+00:00
#
# ...

# %% [markdown]
# **JSON_Dataset 2**: Contains the percentages of providers who have or have not gotten the influenze vaccines from 2016 - 2017
#
#
# **Columns**
#
# **1. Facility Name**
#
# * Contains the name of the medical facility.
#
# **2. Overall Percent**
#
# *  Contains the percentage of providers that have the vaccine.
#
# **3. Overall Declined Percent**
#
# *  Contains the percentage of providers that declined having the vaccine.
#
# **4. Overall Unknown Percent**
#
# *  Contains the percentage of providers that have not answered.
#
# **5. Icon**
#
# *  Contains a link with an image associated with the organization.
#
# **6. Met HP2020 Goal**
#
# * Contains a yes/no for if the facility has meet the healthy people goal of 2020
#
# **7. Zip Code**
#
# * Contains the zip code in which the facility reside.
#
# **8. Location**
#
# * Contains the address in which the facility resides.

# %%
df7 = '/content/HealthcareWorkerVaccinations.json'
read_json2 = pd.read_json(df7)
read_json2.head(11)
# Out:
#                    :id           :version                      :created_at  \
# 0   row-pcc6.n35g-96r7  rv-kyj8-hpve.w8hn 2019-09-12 16:25:50.958000+00:00
# 1   row-8z5c-m9yj~pc33  rv-jqg5.fmgb.gi77 2019-09-12 16:25:50.958000+00:00
# 2   row-p5zc~wwi8.b5id  rv-nabf.rg32.fzqy 2019-09-12 16:25:50.958000+00:00
# 3   row-6ceq~umfw_3bx2  rv-a5je~z2fs_5jg8 2019-09-12 16:25:50.958000+00:00
# 4   row-mkt9-96ic~hjrs  rv-7sp4.4gat-tpyj 2019-09-12 16:25:50.958000+00:00
# 5   row-3wcw~9bv2~ii5n  rv-gbyh.ye9w.z4f9 2019-09-12 16:25:50.958000+00:00
# 6   row-9gpq.cid2.6xh9  rv-g7h6.nnzp_f4a4 2019-09-12 16:25:50.958000+00:00
# 7   row-uz75.35b6.jagc  rv-ganw-qxmk.q52a 2019-09-12 16:25:50.958000+00:00
# 8   row-45e3_hd87~tmtd  rv-5ezr-vekn~gmji 2019-09-12 16:25:50.958000+00:00
# 9   row-xs3a-q83c.x8wk  rv-djqd-ix6t~6icf 2019-09-12 16:25:50.958000+00:00
# 10  row-b3vf-m83r.86br  rv-6fv3-pmm2_73te 2019-09-12 16:25:50.958000+00:00
#
# ...

# %% [markdown]
# **JSON_Dataset 3**: Contains Healthcare worker influenza vaccination information for dialysis facilities in 2016 - 2017
#
#
# **Columns**
#
# **1. Facility Name**
#
# * Contains the name of the medical facility.
#
# **2. Overall Percent**
#
# *  Contains the percentage of providers that have the vaccine.
#
# **3. Overall Declined Percent**
#
# *  Contains the percentage of providers that declined having the vaccine.
#
# **4. Overall Unknown Percent**
#
# *  Contains the percentage of providers that have not answered.
#
# **5. Icon**
#
# *  Contains a link with an image associated with the organization.
#
# **6. Met HP2020 Goal**
#
# * Contains a yes/no for if the facility has meet the healthy people goal of 2020
#
# **7. Zip Code**
#
# * Contains the zip code in which the facility reside.
#
# **8. Location**
#
# * Contains the address in which the facility resides.

# %%
df8 = '/content/query.json'
read_json3 = pd.read_json(df8)
read_json3.head(11)
# Out:
#                    :id           :version                      :created_at  \
# 0   row-8zq8_4qta~mfa5  rv-mztz_3udu.ixhv 2019-09-12 16:44:09.758000+00:00
# 1   row-uuac_be8c_w7kp  rv-eyyu~iw4h_n2j7 2019-09-12 16:44:09.758000+00:00
# 2   row-7niv~kgdz_5zye  rv-ybha.tgqq~dxur 2019-09-12 16:44:09.758000+00:00
# 3   row-fnpc-sqag~4gry  rv-b2ae-c68e-c3sa 2019-09-12 16:44:09.758000+00:00
# 4   row-5zt8.ee2f~2uk2  rv-c7sp-r58z~7bbv 2019-09-12 16:44:09.758000+00:00
# 5   row-r3xp~wk7s.db9d  rv-si63~dp5r-nx3m 2019-09-12 16:44:09.758000+00:00
# 6   row-dsic-5939_i2ie  rv-dk5j_gus4_scdc 2019-09-12 16:44:09.758000+00:00
# 7   row-cvm9~6reb_5vt9  rv-ami3.czrj~magv 2019-09-12 16:44:09.758000+00:00
# 8   row-s24a_7zs7.zdb7  rv-527c.f2tv-78h7 2019-09-12 16:44:09.758000+00:00
# 9   row-24u2_am69_8e7h  rv-27m3.396m_k2u4 2019-09-12 16:44:09.758000+00:00
# 10  row-bxi6_gdpw.irat  rv-5d4i~nbn2-ske9 2019-09-12 16:44:09.758000+00:00
#
# ...
